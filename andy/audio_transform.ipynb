# %% [markdown]
# Provide authentication credentials to your application code by setting the environment variable GOOGLE_APPLICATION_CREDENTIALS
#
# ``` shell
# export GOOGLE_APPLICATION_CREDENTIALS="[Credential File].json"
# ```
#
# This variable only applies to your current shell session, so if you open a new session, set the variable again.

# %%
from subprocess import Popen, run
from os import walk, system
from os.path import splitext

# %%
def sort_file(filename):
    return int(filename.split('_')[0])

def convert_to_flac():
    for (root, dirs, files) in walk('./audios/alphago_news_us'):
        p = []
        for file in files:
            new_file = splitext(file)[0] + '.flac'
            command = 'ffmpeg -i "./audios/alphago_news_us/%s" -ac 1 "./audios/alphago_news_us_flac/%s"' % (file, new_file)
            system(command)

# %%
from speech_to_text import Translator
translator = Translator()

# %%
for (root, dirs, files) in walk ('./audios/alphago_news_us_flac'):
    files.sort(key=lambda file: sort_file(file))
    for filename in files[:1]:
        print ('Translating %s...' % filename)
        gs_uri = translator.upload_to_gcs('./audios/alphago_news_us_flac/%s' % filename)
        results = translator.translate_long(gs_uri)
        translator.delete_from_gcs(filename)
        text_file = splitext(filename)[0] + '.txt'
        with open('./audios/alphago_news_us_text/%s' % (text_file), 'w+') as f:
            f.write(results)

# %%
import json
for (root, dirs, files) in walk ('./audios/alphago_news_us_flac/'):
    files.sort(key=lambda file: sort_file(file))
    n = 5
    for filename in files[n:]:
        print ('%d Translating %s...' % (n, filename))
        gs_uri = translator.upload_to_gcs('./audios/alphago_news_us_flac/%s' % filename)
        results = translator.translate_with_timestamps(gs_uri)
        translator.delete_from_gcs(filename)
        json_file = splitext(filename)[0] + '.json'
        with open('./audios/alphago_news_us_text_timestamps/%s' % (json_file), 'w+') as f:
            json.dump(results, f)
# Out:
# 5 Translating 14_Google AlphaGo Program Beats Go Champ.flac...
# 5 Translating 18_AlphaGo takes first victory against Lee Se-dol.flac...
# 5 Translating 19_AlphaGo becomes number 1 Go player in the world.flac...
# 5 Translating 20_Lee Se-dol beats AlphaGo in match four of five-game series.flac...
# 5 Translating 21_Implications of historic match between Lee Se-dol and AlphaGO.flac...
# 5 Translating 24_AlphaGo wins the third game of the historic match.flac...
# 5 Translating 25_Game over Google programme wins series against Go champion in victory for AI.flac...
# 5 Translating 26_AlphaGo Official Trailer.flac...
# 5 Translating 27_AlphaGo beats Chinese master Koreas Lee Se-dol only human to beat AI.flac...
# 5 Translating 30_Korean grandmaster confident about upcoming Go match with AlphaGO.flac...
# 5 Translating 31_Third game of Lee Se-dol and AlphaGo.flac...
# 5 Translating 34_Inside Googles DeepMind Project How AI Is Learning on Its Own  Max Tegmark.flac...
# 5 Translating 36_Ke Jie loses first match to AlphaGo.flac...
# 5 Translating 37_Space Invaders  DeepMind  WIRED.flac...
# 5 Translating 40_Google DeepMinds Deep Q-learning playing Atari Breakout.flac...
# 5 Translating 42_AlphaGo Strides made in Artificial Intelligence development.flac...
# 5 Translating 43_World top weiqi player Ke Jie loses 2nd match against AlphaGo.flac...
# 5 Translating 44_AskChina How does China view AlphaGos victory.flac...
# 5 Translating 45_Googles DeepMind AI Just Taught Itself To Walk.flac...
# 5 Translating 46_Place your bets in our AlphaGo vs Ke Jie poll.flac...
# 5 Translating 50_Google AlphaGo AI defeats team of five leading Go players.flac...
# 5 Translating 52_Exclusive Ke Jie wants you to know weiqi is fun -- and easy to learn.flac...
# 5 Translating 54_Googles AI Takes Control Of Search  Tech Bet  CNBC.flac...
# 5 Translating 57_Human prodigy is no match for Googles supercomputer.flac...
# 5 Translating 60_Google DeepMind Artificial intelligence helps us save money on electricity bills.flac...
# 5 Translating 61_Man vs Machine What Happens When Machines Can Learn (Pedro Domingos).flac...
# 5 Translating 62_Google AI can predict if hospital patients will die.flac...
# 5 Translating 65_AlphaGo The First Computer Go Program To Beat A Human Go Player.flac...
# 5 Translating 68_MIT Investing 1 Billion in Artificial Intelligence Computing.flac...
# 5 Translating 69_Korea plans to build supercomputer faster than AlphaGo.flac...
# 5 Translating 70_Future Belongs to AI Says Chinese Go Prodigy after Losing to AlphaGo.flac...
# 5 Translating 71_IBM has an AI that can debate a human.flac...
# 5 Translating 72_Go Champion Surprised to Be Defeated by Googles Alphago.flac...
# 5 Translating 73_AI creates movie trailer and other tech news - BBC Click.flac...
# 5 Translating 74_World Shocked as AlphaGo Computer Beats Human Go Champion for 2nd Time.flac...
# 5 Translating 76_Demis Hassabis On Alpha Go And the Future of Go Summit.flac...
# 5 Translating 78_Nature is reclaiming ruined city of Marawi after ISIS retreat.flac...
# 5 Translating 79_Chinas self-developed AI beats top ranking Go player.flac...
# 5 Translating 81_Lee Sedol AlphaGo Start Final Go Match.flac...
# 5 Translating 83_Google artificial intelligence defeats Chinese Go master.flac...
# 5 Translating 85_AlphaGo is Stronger Than Expected Chinese Go Master.flac...
# 5 Translating 88_Will artificial intelligence help us solve every problem.flac...
# 5 Translating 90_AlphaGo Routs Lee in Historic Computer-vs-Human Go Match.flac...
# 5 Translating 94_Stephen Hawking Warns About AI Development  CNBC.flac...
# 5 Translating 95_AI Program AlphaGo Beats Worlds Top Go Player in First of 3 Games.flac...
# 5 Translating 96_How artificial intelligence is transforming medicine.flac...
# 5 Translating 98_Video Refutes ISIS Claim That US Blew Up Mosque   NYT Investigates.flac...
# 5 Translating 102_The Big Picture Will Artificial Intelligence replace humans.flac...
# 5 Translating 104_Googles AlphaGo Beats World Champion Lee Se-Dol.flac...
# 5 Translating 105_Google AI aiding Pentagon with drone strikes.flac...
# 5 Translating 107_AI robots face human opponents in curling match.flac...
# 5 Translating 110_Elon Musk Says DeepMind Win Means AI Is Further Than We Thought.flac...
# 5 Translating 115_Jobs that could be replaced by Artificial Intelligence.flac...
# 5 Translating 116_AlphaGo Defeats Ke Jie in Second Round of Three match Contest.flac...
# 5 Translating 118_Google Quantum AI Labs Purrplexing Discovery.flac...
# 5 Translating 120_Google to open AI center in China.flac...
# 5 Translating 121_AI robots face human opponents in curling match.flac...
# 5 Translating 122_We lost everything Camp established for civilians fleeing ISIS-besieged Philippines city.flac...
# 5 Translating 123_Koreas ADAMs system combines artificial intelligence and virtual reality.flac...
# 5 Translating 125_Uber banned from Italy Google said to pay women less than men (Tech Today).flac...
# 5 Translating 127_US shale oil producers boost production.flac...
# 5 Translating 129_Microsoft shows advances in AI.flac...
# 5 Translating 131_Is Donald Trump A Fascist.flac...
# 5 Translating 133_Garry Kasparov welcomes artificial intelligence - BBC Click.flac...
# 5 Translating 136_Robots and AI changing the healthcare industry.flac...
# 5 Translating 141_AI is gradually reshaping China.flac...
# 5 Translating 142_Attacked by ISIS on the road to Mosul.flac...
# 5 Translating 144_Phone video shows United passenger being pulled off plane (CNET News).flac...
# 5 Translating 145_Medical Diagnosis from Your Google Home.flac...
# 5 Translating 146_US Iraqs Mosul Dam in danger of collapse.flac...
# 5 Translating 148_Amazon Alexa now wants you to go hands-free in a car.flac...
# 5 Translating 149_Magnus Official Trailer 1 (2016) - Documentary.flac...
# 5 Translating 152_AI expected to give China its biggest economic boost.flac...
# 5 Translating 153_2018 World Medical Innovation Forum   Artificial Intelligence.flac...
# 5 Translating 155_US joins Philippines to fight ISIS groups.flac...
# 5 Translating 159_O Homem de Ferro da Vida Real  Peixe Babel 5.flac...
# 5 Translating 164_Inside Assads Syria VICE on HBO Season Premiere (Preview).flac...
# 5 Translating 166_AI detectives are cracking open the black box of deep learning.flac...
# 5 Translating 167_G7 summit ends deadlocked on climate change.flac...
# 5 Translating 169_AI vs Human The Greatest Go Tournament Ever.flac...
# 5 Translating 170_How to play Baduk or Go.flac...
# 5 Translating 175_NBC Brian Williams suspended for 6 months without pay NBC    6.flac...
# 5 Translating 176_Trump meets Israeli Palestinian leaders - in effort to revive peace talks.flac...
# 5 Translating 177_3 ways Artificial Intelligence will impact our future  Max Tegmark.flac...
# 5 Translating 179_Ivine and Pillow  Unfairy Tales  UNICEF USA.flac...
# 5 Translating 181_Pair Go at Go Congress.flac...
# 5 Translating 188_13 of the smartest Artificial Intelligence companies according to MIT.flac...
# 5 Translating 189_Power Rangers (2017) - Go Go Power Rangers Scene (610)  Movieclips.flac...
# 5 Translating 190_Philippines inspects N Korean ship in first act under UN sanctions.flac...
# 5 Translating 191_How is Korea preparing for the 4th Industrial Revolution.flac...
# 5 Translating 194_Rocket Lab launches into space from private site for first time.flac...
# 5 Translating 195_Medical Diagnosis With AI.flac...
# 5 Translating 196_Using machine learning and AI to reduce hospital readmissions.flac...
# 5 Translating 197_   CCTV.flac...
# 5 Translating 199_    Kalke Priyar Biye  Shanto  Bangla Song  Sad Song  Bangla Music Video.flac...
# 5 Translating 200_China hosts World Electronic Sports Games.flac...
# 5 Translating 201_Amazon is Hiring 400 New Employees to Boost AI Offering.flac...
# 5 Translating 202_The Fukushima Nuclear Disaster 5 Years Later.flac...
# 5 Translating 205_China Eastern jet skids off runway at Hong Kong airport.flac...
# 5 Translating 206_Clive Davis The Soundtrack of Our Lives Trailer 1 (2017)  Movieclips Indie.flac...
# 5 Translating 207_The Princess Bride (812) Movie CLIP - Miracle Max (1987) HD.flac...
# 5 Translating 208_Philippines Conducts ISIS Air Strikes.flac...
# 5 Translating 210_Cruise ship begins Silk Road sea route journey from Italy.flac...
# 5 Translating 218_Tsunami Japan 2011 5 Years Later  Snapshots For Onagawa.flac...
# 5 Translating 220_230 years of Korean Catholicism exhibited at Vatican Museum starting Sept 9th.flac...
# 5 Translating 221_Demis Hassabis on BBC News.flac...
# 5 Translating 222_Googles New Healthcare Project.flac...
# 5 Translating 223_Iran Fires 2 Missiles Marked With Israel Must Be Wiped Out.flac...
# 5 Translating 224_Victoria Station remains closed in wake of Manchester Arena attack.flac...
# 5 Translating 225_WEF chair visits Seoul to discuss Koreas place in Fourth Industrial Revolution.flac...
# 5 Translating 226_The Akron Holy War Trailer 1 (2017)  Movieclips Indie.flac...
# 5 Translating 228_Smart senses for robots  Science News.flac...
# 5 Translating 231_Norway mass murderer Breivik sues over his human rights.flac...
# 5 Translating 232_Boston Dynamics - Atlas Robot Jogging Tests 1080p.flac...
# 5 Translating 237_Hilton and IBM Pilot Connie The Worlds First Watson-Enabled Hotel Concierge.flac...
# 5 Translating 240_Can this robot build an IKEA chair faster than you.flac...
# 5 Translating 244_LipNet How easy do you think lipreading is.flac...
# 5 Translating 247_Story behind the AlphaGo vs LEE SeDol match ( vs  9  ).flac...
# 5 Translating 251_Elon Musk Fear To Google DeepMind Artificial intelligence and Neural Network.flac...
# 5 Translating 258_AlphaZero beats Stockfish.flac...
# 5 Translating 260_Rare Bird Babies Jump off Nest in Northeast China.flac...
# 5 Translating 261_Ke Jie hopes for more exciting second match after AlphaGo defeat.flac...
# 5 Translating 264_Testing Human Vs AI.flac...
# 5 Translating 265_12 Google Employees Resigned Against Evil Google Project Maven - AI Warfare.flac...
# 5 Translating 267_Google DeepMind Artari Plays Pacman.flac...
# 5 Translating 272_BYE BYE SHONEN JUMP MAGAZINE.flac...
# 5 Translating 273_Homogeneous Empty Time Trailer  SGIFF 2017.flac...
# 5 Translating 276_ACTION US Special forces in Marawi Philippines   DUNIA KOMANDO 2018.flac...
# 5 Translating 277_F-16 Accidentally Blown Up By Technician By  NEWS WEEK .flac...
# 5 Translating 279_Philippines ISIS-Linked Group Leader Hapilon Hiding in Marawi Mosque.flac...
# 5 Translating 281_Googles AI DeepMind defeats worlds strongest Go Player new milestone in Artificial intelligence.flac...
# 5 Translating 282_Emergence of Locomotion Behaviours in Rich Environments.flac...
# 5 Translating 283_Exclusive interview with Nie Weiping on AlphaGo.flac...
# 5 Translating 288_Philippine Troops Raise Flag For Independence Day As Bombs Fall On Isis-Held City.flac...
# 5 Translating 294_Man vs Machine Ill treat AlphaGo as a human says Ke Jie.flac...
# 5 Translating 295_Chinese Weiqi masters entertain audience with AlphaGo.flac...
# 5 Translating 297_AGA Broadcast Update AlphaGo Zero.flac...
# 5 Translating 298_Googles AI Beats Worlds Best Go Player.flac...
# 5 Translating 308_CES 2018 Sophia the robot on Siri and Alexa - BBC News.flac...
# 5 Translating 309_Googles DeepMind Attacks Starcraft II Next.flac...
# 5 Translating 312_China Startup Everyones talking about AI whats next.flac...
# 5 Translating 314_Sambalpurs Ajay Agarwal Gets Place In Limca Book of Records For His Rare Collection.flac...
# 5 Translating 322_AI Vs Man Most talented people compete against nearly 30 AI machines.flac...
# 5 Translating 323_Rusev blindsides John Cena ahead of their Flag Match SmackDown LIVE July 18 2017.flac...
# 5 Translating 325_DeepMinds AI Learns Audio And Video Concepts By Itself  Two Minute Papers 184.flac...
# 5 Translating 327_AI technology to help workers find jobs.flac...
# 5 Translating 328_Disneys Frozen - Let It Go Sing-Along Version.flac...
# 5 Translating 329_A Navy SEAL explains what to do if youre attacked by a dog.flac...
# 5 Translating 331_Watch  Place where last Mughal Emperor Bahadur Shah Zafar was actually buried.flac...
# 5 Translating 333_Como usar o YouTube Go para ver vdeos offline.flac...
# 5 Translating 342_STAR ZOOM INBTS()s Rap Monster() Shows African American Englis 150825 EP22.flac...
